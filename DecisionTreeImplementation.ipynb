# %% [markdown]
# ## Decision Tree

# %%
import numpy as np
import pandas as pd
from sklearn.datasets import load_iris
from collections import Counter

# %% [markdown]
# ## Load the Iris dataset

# %%
iris = load_iris()
data = iris.data
target = iris.target
feature_names = iris.feature_names

# %% [markdown]
# ## Function to calculate entropy

# %%
def entropy(y):
    hist = np.bincount(y)
    ps = hist / len(y)
    return -np.sum([p * np.log2(p) for p in ps if p > 0])

# %% [markdown]
# ## Function to calculate information gain

# %%
def information_gain(X, y, feature):
    # Calculate original entropy
    original_entropy = entropy(y)
    
    # Split the data
    values = set(X[:, feature])
    weighted_entropy = 0
    for v in values:
        sub_y = y[X[:, feature] == v]
        weighted_entropy += (len(sub_y) / len(y)) * entropy(sub_y)
    
    # Information Gain
    gain = original_entropy - weighted_entropy
    return gain

# %% [markdown]
# ## Function to print decision tree steps

# %%
def print_tree(X, y, feature_names, level=0):
    if len(set(y)) == 1:
        print(f"Level {level}")
        print(f"Count of {y[0]} = {len(y)}")
        print(f"Current Entropy is = {entropy(y):.6f}")
        print("Reached leaf Node")
        return

    # Calculate entropy
    current_entropy = entropy(y)
    # Find the best feature to split
    gains = [information_gain(X, y, f) for f in range(X.shape[1])]
    best_feature = np.argmax(gains)
    best_gain = gains[best_feature]
    
    # Print current state
    counts = Counter(y)
    print(f"Level {level}")
    for class_val, count in counts.items():
        print(f"Count of {class_val} = {count}")
    print(f"Current Entropy is = {current_entropy:.6f}")
    print(f"Splitting on feature {feature_names[best_feature]} with gain ratio {best_gain:.6f}")
    
    # Split the dataset
    values = set(X[:, best_feature])
    for v in values:
        sub_X = X[X[:, best_feature] == v]
        sub_y = y[X[:, best_feature] == v]
        print_tree(sub_X, sub_y, feature_names, level + 1)

# Run the decision tree and print steps
print_tree(data, target, feature_names)
# Out:
# Level 0
# Count of 0 = 50
# Count of 1 = 50
# Count of 2 = 50
# Current Entropy is = 1.584963
# Splitting on feature petal length (cm) with gain ratio 1.446317
# Level 1
# Count of 0 = 4
# Current Entropy is = -0.000000
# Reached leaf Node
# Level 1
# Count of 0 = 13
# Current Entropy is = -0.000000
# Reached leaf Node
# Level 1
# Count of 0 = 7
# Current Entropy is = -0.000000
# Reached leaf Node
# Level 1
# Count of 0 = 7
# Current Entropy is = -0.000000
# Reached leaf Node
# Level 1
# Count of 0 = 13
# Current Entropy is = -0.000000
# Reached leaf Node
# Level 1
# Count of 0 = 1
# Current Entropy is = -0.000000
# Reached leaf Node
# Level 1
# Count of 0 = 2
# Current Entropy is = -0.000000
# Reached leaf Node
# Level 1
# Count of 0 = 1
# Current Entropy is = -0.000000
# Reached leaf Node
# Level 1
# Count of 0 = 2
# Current Entropy is = -0.000000
# Reached leaf Node
# Level 1
# Count of 1 = 5
# Current Entropy is = -0.000000
# Reached leaf Node
# Level 1
# Count of 1 = 7
# Count of 2 = 1
# Current Entropy is = 0.543564
# Splitting on feature sepal length (cm) with gain ratio 0.543564
# Level 2
# Count of 2 = 1
# Current Entropy is = -0.000000
# Reached leaf Node
# Level 2
# Count of 1 = 1
# Current Entropy is = -0.000000
# Reached leaf Node
# Level 2
# Count of 1 = 2
# Current Entropy is = -0.000000
# Reached leaf Node
# Level 2
# Count of 1 = 1
# Current Entropy is = -0.000000
# Reached leaf Node
# Level 2
# Count of 1 = 1
# Current Entropy is = -0.000000
# Reached leaf Node
# Level 2
# Count of 1 = 1
# Current Entropy is = -0.000000
# Reached leaf Node
# Level 2
# Count of 1 = 1
# Current Entropy is = -0.000000
# Reached leaf Node
# Level 1
# Count of 1 = 2
# Count of 2 = 3
# Current Entropy is = 0.970951
# Splitting on feature sepal width (cm) with gain ratio 0.970951
# Level 2
# Count of 1 = 1
# Current Entropy is = -0.000000
# Reached leaf Node
# Level 2
# Count of 2 = 1
# Current Entropy is = -0.000000
# Reached leaf Node
# Level 2
# Count of 1 = 1
# Current Entropy is = -0.000000
# Reached leaf Node
# Level 2
# Count of 2 = 1
# Current Entropy is = -0.000000
# Reached leaf Node
# Level 2
# Count of 2 = 1
# Current Entropy is = -0.000000
# Reached leaf Node
# Level 1
# Count of 1 = 5
# Current Entropy is = -0.000000
# Reached leaf Node
# Level 1
# Count of 1 = 1
# Count of 2 = 3
# Current Entropy is = 0.811278
# Splitting on feature sepal length (cm) with gain ratio 0.811278
# Level 2
# Count of 2 = 1
# Current Entropy is = -0.000000
# Reached leaf Node
# Level 2
# Count of 2 = 1
# Current Entropy is = -0.000000
# Reached leaf Node
# Level 2
# Count of 1 = 1
# Current Entropy is = -0.000000
# Reached leaf Node
# Level 2
# Count of 2 = 1
# Current Entropy is = -0.000000
# Reached leaf Node
# Level 1
# Count of 2 = 2
# Current Entropy is = -0.000000
# Reached leaf Node
# Level 1
# Count of 1 = 2
# Current Entropy is = -0.000000
# Reached leaf Node
# Level 1
# Count of 1 = 1
# Current Entropy is = -0.000000
# Reached leaf Node
# Level 1
# Count of 1 = 3
# Current Entropy is = -0.000000
# Reached leaf Node
# Level 1
# Count of 1 = 4
# Current Entropy is = -0.000000
# Reached leaf Node
# Level 1
# Count of 1 = 3
# Current Entropy is = -0.000000
# Reached leaf Node
# Level 1
# Count of 1 = 1
# Count of 2 = 7
# Current Entropy is = 0.543564
# Splitting on feature sepal length (cm) with gain ratio 0.543564
# Level 2
# Count of 2 = 3
# Current Entropy is = -0.000000
# Reached leaf Node
# Level 2
# Count of 2 = 1
# Current Entropy is = -0.000000
# Reached leaf Node
# Level 2
# Count of 2 = 1
# Current Entropy is = -0.000000
# Reached leaf Node
# Level 2
# Count of 1 = 1
# Current Entropy is = -0.000000
# Reached leaf Node
# Level 2
# Count of 2 = 1
# Current Entropy is = -0.000000
# Reached leaf Node
# Level 2
# Count of 2 = 1
# Current Entropy is = -0.000000
# Reached leaf Node
# Level 1
# Count of 2 = 2
# Current Entropy is = -0.000000
# Reached leaf Node
# Level 1
# Count of 2 = 6
# Current Entropy is = -0.000000
# Reached leaf Node
# Level 1
# Count of 2 = 3
# Current Entropy is = -0.000000
# Reached leaf Node
# Level 1
# Count of 2 = 2
# Current Entropy is = -0.000000
# Reached leaf Node
# Level 1
# Count of 2 = 1
# Current Entropy is = -0.000000
# Reached leaf Node
# Level 1
# Count of 2 = 3
# Current Entropy is = -0.000000
# Reached leaf Node
# Level 1
# Count of 2 = 1
# Current Entropy is = -0.000000
# Reached leaf Node
# Level 1
# Count of 2 = 1
# Current Entropy is = -0.000000
# Reached leaf Node
# Level 1
# Count of 1 = 1
# Current Entropy is = -0.000000
# Reached leaf Node
# Level 1
# Count of 1 = 2
# Current Entropy is = -0.000000
# Reached leaf Node
# Level 1
# Count of 1 = 1
# Current Entropy is = -0.000000
# Reached leaf Node
# Level 1
# Count of 1 = 1
# Current Entropy is = -0.000000
# Reached leaf Node
# Level 1
# Count of 1 = 4
# Current Entropy is = -0.000000
# Reached leaf Node
# Level 1
# Count of 1 = 2
# Count of 2 = 2
# Current Entropy is = 1.000000
# Splitting on feature sepal length (cm) with gain ratio 1.000000
# Level 2
# Count of 2 = 1
# Current Entropy is = -0.000000
# Reached leaf Node
# Level 2
# Count of 1 = 1
# Current Entropy is = -0.000000
# Reached leaf Node
# Level 2
# Count of 1 = 1
# Current Entropy is = -0.000000
# Reached leaf Node
# Level 2
# Count of 2 = 1
# Current Entropy is = -0.000000
# Reached leaf Node
# Level 1
# Count of 1 = 2
# Current Entropy is = -0.000000
# Reached leaf Node
# Level 1
# Count of 2 = 3
# Current Entropy is = -0.000000
# Reached leaf Node
# Level 1
# Count of 2 = 2
# Current Entropy is = -0.000000
# Reached leaf Node
# Level 1
# Count of 2 = 3
# Current Entropy is = -0.000000
# Reached leaf Node
# Level 1
# Count of 2 = 2
# Current Entropy is = -0.000000
# Reached leaf Node
# Level 1
# Count of 2 = 1
# Current Entropy is = -0.000000
# Reached leaf Node
# Level 1
# Count of 2 = 2
# Current Entropy is = -0.000000
# Reached leaf Node
# Level 1
# Count of 1 = 3
# Current Entropy is = -0.000000
# Reached leaf Node

# %% [markdown]
# ## import libraries

# %%
from sklearn.datasets import load_iris
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import export_graphviz
# !pip install graphviz scikit-learn
import graphviz
import pydotplus
# Out:
# Requirement already satisfied: graphviz in c:\users\srish\anaconda3\lib\site-packages (0.20.3)
# Requirement already satisfied: scikit-learn in c:\users\srish\anaconda3\lib\site-packages (1.2.2)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\srish\anaconda3\lib\site-packages (from scikit-learn) (1.26.4)
# Requirement already satisfied: scipy>=1.3.2 in c:\users\srish\anaconda3\lib\site-packages (from scikit-learn) (1.11.4)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\srish\anaconda3\lib\site-packages (from scikit-learn) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\srish\anaconda3\lib\site-packages (from scikit-learn) (2.2.0)

# %% [markdown]
# ## fitting the data

# %%
cl=DecisionTreeClassifier()
cl.fit(data,target)
# Out:
# DecisionTreeClassifier()

# %% [markdown]
# ## exporting data

# %%
# !pip install pydotplus scikit-learn
# Out:
# Requirement already satisfied: pydotplus in c:\users\srish\anaconda3\lib\site-packages (2.0.2)
# Requirement already satisfied: scikit-learn in c:\users\srish\anaconda3\lib\site-packages (1.2.2)
# Requirement already satisfied: pyparsing>=2.0.1 in c:\users\srish\anaconda3\lib\site-packages (from pydotplus) (3.0.9)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\srish\anaconda3\lib\site-packages (from scikit-learn) (1.26.4)
# Requirement already satisfied: scipy>=1.3.2 in c:\users\srish\anaconda3\lib\site-packages (from scikit-learn) (1.11.4)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\srish\anaconda3\lib\site-packages (from scikit-learn) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\srish\anaconda3\lib\site-packages (from scikit-learn) (2.2.0)

# %%
import pydotplus
dot_data = export_graphviz(cl, out_file=None, 
                           feature_names=iris.feature_names,  
                           class_names=iris.target_names,  
                           filled=True, rounded=True,) 
graph=pydotplus.graph_from_dot_data(dot_data)

graph.write_pdf("iris1.pdf")
